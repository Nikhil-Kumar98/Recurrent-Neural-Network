# %%
#Simple RNN Trial 3
print("Simple RNN Trial 3 :- ")

import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential, Input
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout


# Set the directory path where the dataset is stored
base_path = r"/content/drive/MyDrive/WithFolderStructure_2796"

# Function to load and preprocess data from files
def load_data(base_path):
    #Two empty lists are created
    data = [] #This will store the sensor data for each recipe as a sequence of numeric values sensor readings.
    labels = [] #holds the actual recipe class for each data sample.
    recipes = ["Brownie", "Eggs", "Pizza", "Salad", "Sandwich"] #is a reference list of the recipes , guiding the function on what data to look for.

    # Loop through subjects - To just check the dataset path loaded is right or not like the path exists or not
    if not os.path.exists(base_path):
        print(f"Base path {base_path} does not exist.")
        return data, labels

    #To check for the subjects in the path
    for subject in os.listdir(base_path): #each directory inside base_path corresponds to a different subject in the dataset &returns a list of all the subject folder names.
        subject_path = os.path.join(base_path, subject)#joins base path with subject path
        print(f"\n Processing subject: {subject_path}")

        # Loop for the recipe folders
        for recipe in recipes:
            recipe_path = os.path.join(subject_path, f"S{subject.split('_')[1]}_{recipe}_3DMGX1")#formated string , basically to do like this as -  S01_Brownie_3DMGX1

            # Checking if the recipe folder exists (debugging statement )
            if os.path.exists(recipe_path):
                try:
                    # Print the recipe folder being accessed
                    print(f"Processing recipe: {recipe_path}")

                    # Get the text file for sensor ID 2796
                    sensor_files = [f for f in os.listdir(recipe_path) if f.startswith('2796')]# for each file in the folder, first f represents the each file name
                    if len(sensor_files) == 0:
                        print(f"No sensor file found in {recipe_path}") #Debugging statement
                        continue

                    # Load the file and check its contents
                    file_path = os.path.join(recipe_path, sensor_files[0])
                    print(f"Loading Sensor file: {file_path}")

                    # To seperate values and heaadings
                    df = pd.read_csv(file_path, delimiter='\t', skiprows=2, engine='python') #Python engine for parsing the file to handle any potential formatting issues
                    #read_csv() function is actually used to read files with various delimiters, it’s not limited to comma-separated files (CSV), as delimeter is mentioned \t

                    # Identify numeric columns (ignoring timestamps or non-numeric columns)
                    numeric_columns = df.columns[:-1]  # As last column is non-numeric sys time

                    #  convert all the values in the numeric_columns to numbers or numeric types. If any values can’t be converted text like "abc" they are replaced with NaN.
                    df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')#if there are any values that can’t be converted to numbers like text , the coerce put as NaN
                    # 'coerce' means forcing non-numeric data to become something the function can handle
                    df = df.dropna(subset=numeric_columns)  # Drop rows with NaN in numeric columns , example S07 browine file

                    # Append the cleaned numeric data and the recipe label
                    if not df.empty:
                        data.append(df[numeric_columns].values)  # Only numeric data
                        labels.append(recipe)
                    else:
                        print(f"Data from {file_path} is empty after cleaning.")

                except IndexError:
                    print(f"No sensor file found for {subject} - {recipe}")
            else:
                print(f"Recipe folder {recipe_path} not found.")

    return data, labels


# Load data
X, y = load_data(base_path) # X-> sensor data and y-> recipe labels

# Check if any data was loaded
if len(X) == 0:
    print("No data was loaded. Please check your dataset or file paths.")
else:
    print(f"\n Loaded {len(X)} sequences.")

# Filter out empty sequences
X_filtered = [x for x in X if len(x) > 0]# only sequences with actual data are kept and empty are ignored

# Check if any valid sequences remain - for debugging
if len(X_filtered) == 0:
    print("All sequences are empty after filtering. Please check your data preprocessing.")
else:
    print(f"\n Filtered to {len(X_filtered)} non-empty sequences.")

# Ensure all sequences have the same number of features (columns)
#For example, if the first sequence has a shape of (100, 9), this means there are 100 rows and 9 columns (features), so n_features = 9.
if len(X_filtered) > 0:
    n_features = X_filtered[0].shape[1]  # Get number of features from the first sequence
    X_filtered = [x for x in X_filtered if x.shape[1] == n_features]#if it’s not equal to first sequency, that sequence is removed from the list.

    # Filter for the labels to have the same sequence and Avoiding Misalignment
    y_filtered = [y[i] for i in range(len(y)) if len(X[i]) > 0 and X[i].shape[1] == n_features]

    # Check again if we have valid sequences after filtering by features
    if len(X_filtered) == 0:
        print("No sequences remain after filtering by feature size.")
    else:
        print(f"Filtered to {len(X_filtered)} sequences with consistent feature size.")

    # Proceed with padding and scaling if data is available
    if len(X_filtered) > 0:
        # Pad the sequences so that all data have the same length
        X_padded = pad_sequences(X_filtered, padding='post', dtype='float32') #padding zeros at end to maintain same length

        # Preprocess the data - basically normalizing the data to make sure all features have the same scale mean 0, SD -1
        # RNNs that involve gradient-based optimization perform better when the input data is normalized
        scaler = StandardScaler()
        X_scaled = np.array([scaler.fit_transform(x) for x in X_padded]) #both computes the mean and standard deviation of the data

        # Encode the labels - converting labels into a numeric data like "Brownie" → 0, "Pizza" → 1 ...
        label_encoder = LabelEncoder()
        y_encoded = label_encoder.fit_transform(y_filtered)

        # Check label distribution before splitting
        unique, counts = np.unique(y_filtered, return_counts=True)
        print("\n Label distribution before splitting:")
        print(dict(zip(unique, counts)))

        # Split into train and test sets (80/20)
        X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)
        # stratification is used to ensure that the split between the training and testing sets maintains the equal or same propotion of classes

        # Check label distribution in training and testing sets
        train_unique, train_counts = np.unique(y_train, return_counts=True)
        test_unique, test_counts = np.unique(y_test, return_counts=True)
        print("\n Label distribution in training set:")
        print(dict(zip(train_unique, train_counts)))
        print("\n Label distribution in testing set:")
        print(dict(zip(test_unique, test_counts)))
        print("\n")


        # ------------------- Simple RNN Architecture -------------------
        model = Sequential()
        model.add(Input(shape=(X_train.shape[1], X_train.shape[2])))  # Input layer to define shape
        #Shape of input data = (batch_size, sequence_length, num_features),used 1 and 2 to select sequence and features

        model.add(SimpleRNN(32, return_sequences=False))

        model.add(Dense(128, activation='relu'))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(128, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(32, activation='relu'))


        # Output layer
        model.add(Dense(len(np.unique(y_encoded)), activation='softmax'))
        #model.add(Dense(5)), activation='softmax'))

        #---------------------------------------------------------------
        # Compile the model
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        # Train the model
        history = model.fit(X_train, tf.keras.utils.to_categorical(y_train), epochs=50,
                            batch_size=128,
                            validation_data=(X_test, tf.keras.utils.to_categorical(y_test))) # Convert labels to one-hot encoding

        # Print the final training accuracy
        train_accuracy = history.history['accuracy'][-1] # -1 is used to access the last value in the list, it will give you the final training accuracy after all epochs have completed.
        print(f'\nTraining accuracy: {train_accuracy}')


        # Evaluate the model
        y_pred = np.argmax(model.predict(X_test), axis=-1)

        '''test_predictions = model.predict(test_image_pixcels)
        test_predictions_classes = np.argmax(test_predictions, axis=1)
        test_true_classes = np.argmax(test_labels, axis=1) '''

        # Confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        print("\n Confusion Matrix:")
        print(conf_matrix)

        #plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='viridis', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.title('Confusion Matrix')
        plt.show()

        #-------------------Evalution Parameters-------------------
        # overall accuracy
        accuracy = accuracy_score(y_test, y_pred)
        print("\n Accuracy:", accuracy)

        # Precession for each class
        precision = precision_score(y_test, y_pred, average=None)
        print("\n Precision for each class:")
        print(precision)

        # Macroaverage precision
        macro_precision = precision_score(y_test, y_pred, average='macro')
        print("\n Macroaverage Precision:", macro_precision)

        # Recall for each class
        recall = recall_score(y_test, y_pred, average=None)
        print("\n Recall for each class:")
        print(recall)

        # Macroaverage recall
        macro_recall = recall_score(y_test, y_pred, average='macro')
        print("\n Macroaverage Recall:", macro_recall)

        # F1 score for each class
        f1 = f1_score(y_test, y_pred, average=None)
        print("\n F1 score for each class:")
        print(f1)

        # Macroaverage F1 score
        macro_f1 = f1_score(y_test, y_pred, average='macro')
        print("\n Macroaverage F1 Score:", macro_f1,"\n")
# Out:
# Simple RNN Trial 3 :-
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Brownie_3DMGX1/2796_11-03_10_54_58-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Eggs_3DMGX1/2796_11-03_10_09_24-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Pizza_3DMGX1/2796_11-03_09_55_15-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Salad_3DMGX1/2796_11-03_10_22_43-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_47/S47_Sandwich_3DMGX1/2796_11-03_10_44_42-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Brownie_3DMGX1/2796_11-05_10_39_22-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Eggs_3DMGX1/2796_11-05_10_00_22-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Pizza_3DMGX1/2796_11-05_09_31_55-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Salad_3DMGX1/2796_11-05_10_11_00-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_51/S51_Sandwich_3DMGX1/2796_11-05_10_24_23-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Brownie_3DMGX1/2796_11-04_11_20_44-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Eggs_3DMGX1/2796_11-04_10_35_47-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Pizza_3DMGX1/2796_11-04_10_23_19-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Salad_3DMGX1/2796_11-04_10_51_49-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_49/S49_Sandwich_3DMGX1/2796_11-04_11_03_43-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Brownie_3DMGX1/2796_11-06_10_30_46-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Eggs_3DMGX1/2796_11-06_10_04_48-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Pizza_3DMGX1/2796_11-06_09_41_59-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Salad_3DMGX1/2796_11-06_10_15_20-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_53/S53_Sandwich_3DMGX1/2796_11-06_10_24_51-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Brownie_3DMGX1 not found.
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Eggs_3DMGX1/2796_11-05_15_00_40-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Pizza_3DMGX1/2796_11-05_14_49_04-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Salad_3DMGX1/2796_11-05_15_10_14-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_52/S52_Sandwich_3DMGX1/2796_11-05_15_18_33-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Brownie_3DMGX1/2796_11-04_16_39_33-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Eggs_3DMGX1/2796_11-04_15_42_16-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Pizza_3DMGX1/2796_11-04_15_23_56-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Salad_3DMGX1/2796_11-04_15_54_37-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_50/S50_Sandwich_3DMGX1/2796_11-04_16_27_22-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Brownie_3DMGX1/2796_11-03_16_21_30-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Eggs_3DMGX1/2796_11-03_15_41_24-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Pizza_3DMGX1/2796_11-03_15_26_19-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Salad_3DMGX1/2796_11-03_15_54_35-time-synch.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_48/S48_Sandwich_3DMGX1 not found.
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Brownie_3DMGX1/2796_11-06_13_20_13-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Eggs_3DMGX1/2796_11-06_12_47_25-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Pizza_3DMGX1/2796_11-06_12_32_35-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Salad_3DMGX1/2796_11-06_12_55_24-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_55/S55_Sandwich_3DMGX1/2796_11-06_13_11_15-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Brownie_3DMGX1/2796_11-06_11_55_37-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Eggs_3DMGX1/2796_11-06_11_28_49-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Pizza_3DMGX1/2796_11-06_11_15_02-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Salad_3DMGX1/2796_11-06_11_38_04-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_54/S54_Sandwich_3DMGX1/2796_11-06_11_47_09-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Brownie_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Eggs_3DMGX1 not found.
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Pizza_3DMGX1/2796_10-29_10_13_31-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Salad_3DMGX1/2796_10-29_10_47_33-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_41/S41_Sandwich_3DMGX1/2796_10-29_10_56_14-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Brownie_3DMGX1/2796_10-28_16_29_31-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Eggs_3DMGX1/2796_10-28_15_53_05-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Pizza_3DMGX1/2796_10-28_15_37_00-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Salad_3DMGX1/2796_10-28_16_07_41-time-synch.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_40/S40_Sandwich_3DMGX1 not found.
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Brownie_3DMGX1/2796_10-20_17_12_34-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Eggs_3DMGX1/2796_10-20_16_08_06-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Pizza_3DMGX1/2796_10-20_15_51_44-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Salad_3DMGX1/2796_10-20_16_51_04-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_32/S32_Sandwich_3DMGX1/2796_10-20_17_05_28-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_33
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_33/S33_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_33/S33_Brownie_3DMGX1/2796_10-21_11_18_48-time-synch.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_33/S33_Eggs_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_33/S33_Pizza_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_33/S33_Salad_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_33/S33_Sandwich_3DMGX1 not found.
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Brownie_3DMGX1/2796_10-19_11_30_01-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Eggs_3DMGX1/2796_10-19_10_55_29-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Pizza_3DMGX1/2796_10-19_10_43_07-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Salad_3DMGX1/2796_10-19_11_04_50-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_29/S29_Sandwich_3DMGX1/2796_10-19_11_22_54-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Brownie_3DMGX1/2796_10-19_16_10_06-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Eggs_3DMGX1/2796_10-19_15_34_05-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Pizza_3DMGX1/2796_10-19_15_20_07-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Salad_3DMGX1/2796_10-19_15_44_28-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_30/S30_Sandwich_3DMGX1/2796_10-19_16_00_09-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Brownie_3DMGX1/2796_11-05_12_10_39-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Eggs_3DMGX1/2796_11-05_11_39_26-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Pizza_3DMGX1/2796_11-05_11_24_22-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Salad_3DMGX1/2796_11-05_11_50_53-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_28/S28_Sandwich_3DMGX1/2796_11-05_12_01_18-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Brownie_3DMGX1 not found.
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Eggs_3DMGX1/2796_10-22_15_41_51-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Pizza_3DMGX1/2796_10-22_15_19_43-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Salad_3DMGX1/2796_10-22_16_02_30-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_36/S36_Sandwich_3DMGX1/2796_10-22_16_26_29-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Brownie_3DMGX1/2796_10-22_11_25_26-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Eggs_3DMGX1/2796_10-22_10_36_41-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Pizza_3DMGX1/2796_10-22_10_11_49-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Salad_3DMGX1/2796_10-22_10_59_50-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_35/S35_Sandwich_3DMGX1/2796_10-22_11_17_28-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Brownie_3DMGX1/2796_10-21_16_37_39-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Eggs_3DMGX1/2796_10-21_15_22_10-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Pizza_3DMGX1/2796_10-21_15_04_09-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Salad_3DMGX1/2796_10-21_15_41_18-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_34/S34_Sandwich_3DMGX1/2796_10-21_16_03_59-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Brownie_3DMGX1/2796_10-20_11_03_32-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Eggs_3DMGX1/2796_10-20_10_17_15-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Pizza_3DMGX1/2796_10-20_09_59_14-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Salad_3DMGX1/2796_10-20_10_36_44-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_31/S31_Sandwich_3DMGX1/2796_10-20_10_52_00-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Brownie_3DMGX1/2796_02-11_12_03_08-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Eggs_3DMGX1/2796_02-11_11_13_20-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Pizza_3DMGX1/2796_02-11_11_36_24-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Salad_3DMGX1/2796_02-11_11_26_41-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_20/S20_Sandwich_3DMGX1/2796_02-11_10_41_46-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Brownie_3DMGX1/2796_02-11_17_28_19-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Eggs_3DMGX1/2796_02-11_16_31_40-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Pizza_3DMGX1/2796_02-11_17_05_48-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Salad_3DMGX1/2796_02-11_16_51_03-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_21/S21_Sandwich_3DMGX1/2796_02-11_16_02_39-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Brownie_3DMGX1/2796_02-09_10_38_07-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Eggs_3DMGX1/2796_02-09_10_56_59-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Pizza_3DMGX1/2796_02-09_11_34_45-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Salad_3DMGX1/2796_02-09_11_17_49-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_16/S16_Sandwich_3DMGX1/2796_02-09_10_24_44-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Brownie_3DMGX1/2796_02-13_16_05_11-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Eggs_3DMGX1/2796_02-13_16_20_00-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Pizza_3DMGX1/2796_02-13_16_47_33-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Salad_3DMGX1/2796_02-13_16_37_19-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_25/S25_Sandwich_3DMGX1/2796_02-13_15_52_12-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Brownie_3DMGX1/2796_02-12_10_43_11-time-synch.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Eggs_3DMGX1 not found.
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Pizza_3DMGX1/2796_02-12_11_40_56-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Salad_3DMGX1/2796_02-12_11_22_43-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_22/S22_Sandwich_3DMGX1/2796_02-12_12_01_47-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Brownie_3DMGX1/2796_02-10_16_14_38-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Eggs_3DMGX1/2796_02-10_16_36_20-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Pizza_3DMGX1/2796_02-10_17_13_17-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Salad_3DMGX1/2796_02-10_16_55_27-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_19/S19_Sandwich_3DMGX1/2796_02-10_16_00_22-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Brownie_3DMGX1/2796_02-09_16_53_14-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Eggs_3DMGX1/2796_02-09_17_11_09-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Pizza_3DMGX1/2796_02-09_18_01_16-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Salad_3DMGX1/2796_02-09_17_44_17-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_17/S17_Sandwich_3DMGX1/2796_02-09_16_37_30-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_24
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_24/S24_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_24/S24_Brownie_3DMGX1/2796_02-13_11_34_28-time.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_24/S24_Eggs_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_24/S24_Pizza_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_24/S24_Salad_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_24/S24_Sandwich_3DMGX1 not found.
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_23
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Brownie_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Eggs_3DMGX1 not found.
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Pizza_3DMGX1 not found.
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Salad_3DMGX1/2796_02-12_17_13_56-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_23/S23_Sandwich_3DMGX1/2796_02-12_16_14_29-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Brownie_3DMGX1/2796_02-10_12_00_58-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Eggs_3DMGX1/2796_02-10_11_10_31-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Pizza_3DMGX1/2796_02-10_11_39_59-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Salad_3DMGX1/2796_02-10_11_27_59-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_18/S18_Sandwich_3DMGX1/2796_02-10_10_34_45-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Brownie_3DMGX1/2796_02-06_17_10_24-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Eggs_3DMGX1/2796_02-06_17_57_45-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Pizza_3DMGX1/2796_02-06_18_18_40-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Salad_3DMGX1/2796_02-06_17_42_46-time.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_14/S14_Sandwich_3DMGX1 not found.
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Brownie_3DMGX1/2796_02-04_11_08_31-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Eggs_3DMGX1/2796_02-04_11_49_32-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Pizza_3DMGX1/2796_02-04_12_37_19-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Salad_3DMGX1/2796_02-04_11_29_51-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_12/S12_Sandwich_3DMGX1/2796_02-04_10_50_20-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Brownie_3DMGX1/2796_02-02_16_48_33-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Eggs_3DMGX1/2796_02-02_17_09_38-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Pizza_3DMGX1/2796_02-02_17_49_23-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Salad_3DMGX1/2796_02-02_17_30_36-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_09/S09_Sandwich_3DMGX1/2796_02-02_16_30_59-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Brownie_3DMGX1/2796_02-03_17_45_57-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Eggs_3DMGX1/2796_02-03_18_22_50-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Pizza_3DMGX1/2796_02-03_18_36_37-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Salad_3DMGX1/2796_02-03_18_08_37-time.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_11/S11_Sandwich_3DMGX1 not found.
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Brownie_3DMGX1/2796_02-02_11_16_30-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Eggs_3DMGX1/2796_02-02_11_16_30-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Pizza_3DMGX1/2796_02-02_12_06_05-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Salad_3DMGX1/2796_02-02_11_50_33-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_08/S08_Sandwich_3DMGX1/2796_02-02_11_05_30-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Brownie_3DMGX1/2796_02-06_12_01_26-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Eggs_3DMGX1/2796_02-06_12_42_13-time-synch.txt
# Recipe folder /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Pizza_3DMGX1 not found.
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Salad_3DMGX1/2796_02-06_12_26_01-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_13/S13_Sandwich_3DMGX1/2796_02-06_11_45_57-time.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Brownie_3DMGX1/2796_02-07_11_14_12-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Eggs_3DMGX1/2796_02-07_11_38_14-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Pizza_3DMGX1/2796_02-07_11_49_53-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Salad_3DMGX1/2796_02-07_11_32_43-time-synch.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_15/S15_Sandwich_3DMGX1/2796_02-07_11_23_30-time-synch.txt
#
#  Processing subject: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Brownie_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Brownie_3DMGX1/2796_01-30_16_30_49-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Eggs_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Eggs_3DMGX1/2796_01-30_17_11_20-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Pizza_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Pizza_3DMGX1/2796_01-30_17_29_10-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Salad_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Salad_3DMGX1/2796_01-30_16_53_58-time.txt
# Processing recipe: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Sandwich_3DMGX1
# Loading Sensor file: /content/drive/MyDrive/WithFolderStructure_2796/Subject_07/S07_Sandwich_3DMGX1/2796_01-30_16_15_03-time.txt
#
#  Loaded 169 sequences.
#
#  Filtered to 169 non-empty sequences.
# Filtered to 169 sequences with consistent feature size.
#
#  Label distribution before splitting:
# {'Brownie': 34, 'Eggs': 33, 'Pizza': 34, 'Salad': 36, 'Sandwich': 32}
#
#  Label distribution in training set:
# {0: 27, 1: 26, 2: 27, 3: 29, 4: 26}
#
#  Label distribution in testing set:
# {0: 7, 1: 7, 2: 7, 3: 7, 4: 6}
#
#
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 51s 21s/step - accuracy: 0.1709 - loss: 1.6113 - val_accuracy: 0.2059 - val_loss: 1.6080
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 85s 21s/step - accuracy: 0.2388 - loss: 1.6084 - val_accuracy: 0.2353 - val_loss: 1.6061
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 20s/step - accuracy: 0.2965 - loss: 1.6064 - val_accuracy: 0.2647 - val_loss: 1.6053
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 81s 23s/step - accuracy: 0.2361 - loss: 1.6047 - val_accuracy: 0.2941 - val_loss: 1.6007
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 39s 20s/step - accuracy: 0.2637 - loss: 1.6026 - val_accuracy: 0.3235 - val_loss: 1.5966
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 20s/step - accuracy: 0.2564 - loss: 1.5986 - val_accuracy: 0.2647 - val_loss: 1.5923
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 87s 26s/step - accuracy: 0.2765 - loss: 1.5922 - val_accuracy: 0.2647 - val_loss: 1.5870
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 76s 22s/step - accuracy: 0.3090 - loss: 1.5836 - val_accuracy: 0.2647 - val_loss: 1.5822
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 86s 26s/step - accuracy: 0.3040 - loss: 1.5756 - val_accuracy: 0.2647 - val_loss: 1.5718
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 77s 21s/step - accuracy: 0.3290 - loss: 1.5625 - val_accuracy: 0.2353 - val_loss: 1.5594
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 23s/step - accuracy: 0.3316 - loss: 1.5465 - val_accuracy: 0.2647 - val_loss: 1.5408
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 20s/step - accuracy: 0.3339 - loss: 1.5272 - val_accuracy: 0.2647 - val_loss: 1.5172
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 23s/step - accuracy: 0.3191 - loss: 1.4995 - val_accuracy: 0.2941 - val_loss: 1.4835
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 80s 21s/step - accuracy: 0.3467 - loss: 1.4734 - val_accuracy: 0.3824 - val_loss: 1.4383
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 20s/step - accuracy: 0.3716 - loss: 1.4392 - val_accuracy: 0.2941 - val_loss: 1.4223
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 22s/step - accuracy: 0.3516 - loss: 1.4308 - val_accuracy: 0.3529 - val_loss: 1.3844
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 85s 25s/step - accuracy: 0.3493 - loss: 1.4043 - val_accuracy: 0.3529 - val_loss: 1.3762
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 23s/step - accuracy: 0.3568 - loss: 1.3776 - val_accuracy: 0.3824 - val_loss: 1.2866
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 75s 20s/step - accuracy: 0.3896 - loss: 1.3446 - val_accuracy: 0.4412 - val_loss: 1.2713
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 45s 20s/step - accuracy: 0.4094 - loss: 1.3442 - val_accuracy: 0.3235 - val_loss: 1.4066
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 44s 23s/step - accuracy: 0.3644 - loss: 1.3931 - val_accuracy: 0.3824 - val_loss: 1.2774
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 84s 23s/step - accuracy: 0.4372 - loss: 1.3127 - val_accuracy: 0.3235 - val_loss: 1.2816
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 76s 20s/step - accuracy: 0.3719 - loss: 1.3873 - val_accuracy: 0.3235 - val_loss: 1.2764
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 20s/step - accuracy: 0.3493 - loss: 1.3806 - val_accuracy: 0.5000 - val_loss: 1.2189
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 83s 21s/step - accuracy: 0.3995 - loss: 1.2846 - val_accuracy: 0.5294 - val_loss: 1.3324
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 46s 26s/step - accuracy: 0.4247 - loss: 1.3822 - val_accuracy: 0.3824 - val_loss: 1.3253
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 26s/step - accuracy: 0.4148 - loss: 1.3654 - val_accuracy: 0.6765 - val_loss: 1.2152
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 75s 20s/step - accuracy: 0.4323 - loss: 1.2862 - val_accuracy: 0.5000 - val_loss: 1.2356
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 19s/step - accuracy: 0.3818 - loss: 1.3256 - val_accuracy: 0.5000 - val_loss: 1.2346
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 22s/step - accuracy: 0.3742 - loss: 1.3225 - val_accuracy: 0.5588 - val_loss: 1.2078
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 46s 26s/step - accuracy: 0.4349 - loss: 1.2828 - val_accuracy: 0.6471 - val_loss: 1.1912
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 44s 23s/step - accuracy: 0.4320 - loss: 1.2637 - val_accuracy: 0.5294 - val_loss: 1.2113
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 20s/step - accuracy: 0.4749 - loss: 1.2639 - val_accuracy: 0.5000 - val_loss: 1.1957
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 20s/step - accuracy: 0.4497 - loss: 1.2506 - val_accuracy: 0.5000 - val_loss: 1.1751
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 84s 20s/step - accuracy: 0.4575 - loss: 1.2375 - val_accuracy: 0.3824 - val_loss: 1.2583
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 44s 23s/step - accuracy: 0.3945 - loss: 1.2764 - val_accuracy: 0.4118 - val_loss: 1.1926
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 83s 26s/step - accuracy: 0.3995 - loss: 1.2393 - val_accuracy: 0.5294 - val_loss: 1.1518
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 76s 20s/step - accuracy: 0.4299 - loss: 1.2694 - val_accuracy: 0.4412 - val_loss: 1.1857
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 19s/step - accuracy: 0.4172 - loss: 1.2731 - val_accuracy: 0.5294 - val_loss: 1.2409
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 46s 20s/step - accuracy: 0.3995 - loss: 1.2960 - val_accuracy: 0.5000 - val_loss: 1.3186
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 79s 23s/step - accuracy: 0.3719 - loss: 1.3308 - val_accuracy: 0.6765 - val_loss: 1.1195
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 78s 20s/step - accuracy: 0.4624 - loss: 1.2160 - val_accuracy: 0.5000 - val_loss: 1.1550
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 20s/step - accuracy: 0.4424 - loss: 1.3002 - val_accuracy: 0.5588 - val_loss: 1.1402
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 21s/step - accuracy: 0.4273 - loss: 1.2810 - val_accuracy: 0.7059 - val_loss: 1.1326
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 40s 21s/step - accuracy: 0.4146 - loss: 1.2139 - val_accuracy: 0.4118 - val_loss: 1.2203
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 41s 20s/step - accuracy: 0.4372 - loss: 1.2529 - val_accuracy: 0.3529 - val_loss: 1.3106
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 43s 20s/step - accuracy: 0.3769 - loss: 1.3304 - val_accuracy: 0.5294 - val_loss: 1.2181
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 23s/step - accuracy: 0.4221 - loss: 1.2606 - val_accuracy: 0.5882 - val_loss: 1.1661
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 80s 21s/step - accuracy: 0.4247 - loss: 1.2393 - val_accuracy: 0.4412 - val_loss: 1.1674
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 42s 20s/step - accuracy: 0.4247 - loss: 1.2486 - val_accuracy: 0.4412 - val_loss: 1.1726
#
# Training accuracy: 0.42222222685813904
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 6s/step
#
#  Confusion Matrix:
# [[0 0 2 4 1]
#  [0 2 2 1 2]
#  [0 0 7 0 0]
#  [0 4 2 0 1]
#  [0 0 0 0 6]]
#  Accuracy: 0.4411764705882353
#
#  Precision for each class:
# [0.         0.33333333 0.53846154 0.         0.6       ]
#
#  Macroaverage Precision: 0.2943589743589744
#
#  Recall for each class:
# [0.         0.28571429 1.         0.         1.        ]
#
#  Macroaverage Recall: 0.45714285714285713
#
#  F1 score for each class:
# [0.         0.30769231 0.7        0.         0.75      ]
#
#  Macroaverage F1 Score: 0.3515384615384615
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
